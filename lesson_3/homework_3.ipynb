# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
img = cv2.imread('data/sparrow.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Create a blurred (unsharp) version of the original image (you can use Gaussian blurring)
unsharp = cv2.GaussianBlur(img, ksize=(5,5), sigmaX=5)
plt.imshow(unsharp)

# %%
# Create the difference image (original − unsharp)
# Note: Remember that you are working with uint8 data types. Any addition or substractions
# might result in overflow or underflow, respectively. You can prevent this by casting the images to float.
img.astype(np.float32)
diff = img - unsharp
plt.imshow(diff)

# %%
# Apply USM to get the resulting image using `sharpened = original + (original − unsharp) × amount`
# Note: Again, take care of underflows/overflows if necessary.
amount = 5
sharpened = img + diff * amount
plt.imshow(sharpened)

# %%
#Значение параметра Amount, на мой взгляд, должно зависеть от поставленной задачи.
#При значении ~5 чётко проявляются границы между цветами на изображении.
#При значениях близких к 100 остаются только границы тёмных и светлых областей.
